# %%
import pandas as pd

# %%
iris = pd.read_csv('https://gist.githubusercontent.com/netj/8836201/raw/6f9306ad21398ea43cba4f7d537619d0e07d5ae3/iris.csv')

# %%
print(iris)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
df = iris
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
df.shape
# Out:
# (150, 5)

# %%
df.coloumns = ['s.length', 'sepal.width', 'petal.length', 'petal.width',
       'Flower']
# Out:
# <ipython-input-7-e2996a972d18>:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.coloumns = ['s.length', 'sepal.width', 'petal.length', 'petal.width',

# %%
df.dtypes
# Out:
# sepal.length    float64
# sepal.width     float64
# petal.length    float64
# petal.width     float64
# variety          object
# dtype: object

# %%
df.dtypes
# Out:
# sepal.length    float64
# sepal.width     float64
# petal.length    float64
# petal.width     float64
# variety          object
# dtype: object

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]>

# %%
df.describe()
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df['sepal.length']
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal.length, Length: 150, dtype: float64

# %%
df.isnull()
# Out:
#      sepal.length  sepal.width  petal.length  petal.width  variety
# 0           False        False         False        False    False
# 1           False        False         False        False    False
# 2           False        False         False        False    False
# 3           False        False         False        False    False
# 4           False        False         False        False    False
# ..            ...          ...           ...          ...      ...
# 145         False        False         False        False    False
# 146         False        False         False        False    False
# 147         False        False         False        False    False
# 148         False        False         False        False    False
# 149         False        False         False        False    False
#
# [150 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# sepal.length    0
# sepal.width     0
# petal.length    0
# petal.width     0
# variety         0
# dtype: int64

# %%
df.iloc[1:4, 2:5]
# Out:
#    petal.length  petal.width variety
# 1           1.4          0.2  Setosa
# 2           1.3          0.2  Setosa
# 3           1.5          0.2  Setosa

# %%
df.tail
# Out:
# <bound method NDFrame.tail of      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]>

# %%
df.tail();

# %%
print(df.tail());
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica

# %% [markdown]
# ### Remove the Row from the table

# %%
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
df.drop(3)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# 5             5.4          3.9           1.7          0.4     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [149 rows x 5 columns]

# %%
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
a = df.head()
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
a = df.drop(3)
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
df.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
df.column
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-1031965220f7> in <module>
# ----> 1 df.column
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'column'

# %%
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
iris.drop(1, inplace=True)

# %%
iris.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa
# 5           5.4          3.9           1.7          0.4  Setosa

# %%
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa
# 5           5.4          3.9           1.7          0.4  Setosa

# %%
df.index
# Out:
# Int64Index([  0,   2,   3,   4,   5,   6,   7,   8,   9,  10,
#             ...
#             140, 141, 142, 143, 144, 145, 146, 147, 148, 149],
#            dtype='int64', length=149)

# %%
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa
# 5           5.4          3.9           1.7          0.4  Setosa

# %%
df.drop(df.index[2])
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# 5             5.4          3.9           1.7          0.4     Setosa
# 6             4.6          3.4           1.4          0.3     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [148 rows x 5 columns]

# %%
iris.drop(df.index[2])
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# 5             5.4          3.9           1.7          0.4     Setosa
# 6             4.6          3.4           1.4          0.3     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [148 rows x 5 columns]

# %%
iris.drop(df.index[0:1], inplace=True )

# %%
iris.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa
# 5           5.4          3.9           1.7          0.4  Setosa
# 6           4.6          3.4           1.4          0.3  Setosa
# 7           5.0          3.4           1.5          0.2  Setosa

# %%
iris.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa
# 5           5.4          3.9           1.7          0.4  Setosa
# 6           4.6          3.4           1.4          0.3  Setosa
# 7           5.0          3.4           1.5          0.2  Setosa

# %%
iris.drop(iris.index[0:2])
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 5             5.4          3.9           1.7          0.4     Setosa
# 6             4.6          3.4           1.4          0.3     Setosa
# 7             5.0          3.4           1.5          0.2     Setosa
# 8             4.4          2.9           1.4          0.2     Setosa
# 9             4.9          3.1           1.5          0.1     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [145 rows x 5 columns]

# %%
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa
# 5           5.4          3.9           1.7          0.4  Setosa
# 6           4.6          3.4           1.4          0.3  Setosa
# 7           5.0          3.4           1.5          0.2  Setosa

# %%
iris.columns
# Out:
# Index(['sepal.length', 'sepal.width', 'petal.length', 'petal.width',
#        'variety'],
#       dtype='object')

# %%
iris.columns = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
       'variety']

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width variety
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa
# 5           5.4          3.9           1.7          0.4  Setosa
# 6           4.6          3.4           1.4          0.3  Setosa
# 7           5.0          3.4           1.5          0.2  Setosa

# %%
iris[iris.sepal_length > 5]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    variety
# 5             5.4          3.9           1.7          0.4     Setosa
# 10            5.4          3.7           1.5          0.2     Setosa
# 14            5.8          4.0           1.2          0.2     Setosa
# 15            5.7          4.4           1.5          0.4     Setosa
# 16            5.4          3.9           1.3          0.4     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [117 rows x 5 columns]

# %%
iris[iris.variety == 'Virginica']
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    variety
# 100           6.3          3.3           6.0          2.5  Virginica
# 101           5.8          2.7           5.1          1.9  Virginica
# 102           7.1          3.0           5.9          2.1  Virginica
# 103           6.3          2.9           5.6          1.8  Virginica
# 104           6.5          3.0           5.8          2.2  Virginica
# 105           7.6          3.0           6.6          2.1  Virginica
# 106           4.9          2.5           4.5          1.7  Virginica
# 107           7.3          2.9           6.3          1.8  Virginica
# 108           6.7          2.5           5.8          1.8  Virginica
# 109           7.2          3.6           6.1          2.5  Virginica
# 110           6.5          3.2           5.1          2.0  Virginica
# 111           6.4          2.7           5.3          1.9  Virginica
# 112           6.8          3.0           5.5          2.1  Virginica
# ...

# %%
c1 = iris[iris.variety == 'Virginica'].describe()
# c2 = iris[iris.variety == 'Setosa',].describe()

# %%
print(c1)
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count      50.00000    50.000000     50.000000     50.00000
# mean        6.58800     2.974000      5.552000      2.02600
# std         0.63588     0.322497      0.551895      0.27465
# min         4.90000     2.200000      4.500000      1.40000
# 25%         6.22500     2.800000      5.100000      1.80000
# 50%         6.50000     3.000000      5.550000      2.00000
# 75%         6.90000     3.175000      5.875000      2.30000
# max         7.90000     3.800000      6.900000      2.50000

# %%
c2 = iris[iris.variety == 'Setosa'].describe()

# %%
print(c2)
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count     47.000000    47.000000     47.000000    47.000000
# mean       5.012766     3.440426      1.468085     0.248936
# std        0.360324     0.384289      0.177061     0.108091
# min        4.300000     2.300000      1.000000     0.100000
# 25%        4.800000     3.200000      1.400000     0.200000
# 50%        5.000000     3.400000      1.500000     0.200000
# 75%        5.200000     3.700000      1.600000     0.300000
# max        5.800000     4.400000      1.900000     0.600000

# %% [markdown]
# Adding rows

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width variety
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa
# 5           5.4          3.9           1.7          0.4  Setosa
# 6           4.6          3.4           1.4          0.3  Setosa
# 7           5.0          3.4           1.5          0.2  Setosa

# %%
df.iloc[0]
# Out:
# sepal_length       4.6
# sepal_width        3.1
# petal_length       1.5
# petal_width        0.2
# variety         Setosa
# Name: 3, dtype: object

# %%
df.loc[0] # as there is no 0 row so it will give us error
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df.loc[3]
# Out:
# sepal_length       4.6
# sepal_width        3.1
# petal_length       1.5
# petal_width        0.2
# variety         Setosa
# Name: 3, dtype: object

# %% [markdown]
# Adding row using iloc

# %%
df.iloc[0] = [1,2,3,4,'Tulip']

# %%
# ilock take the position and  will be added at the first of position of the table
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width variety
# 3           1.0          2.0           3.0          4.0   Tulip
# 4           5.0          3.6           1.4          0.2  Setosa
# 5           5.4          3.9           1.7          0.4  Setosa
# 6           4.6          3.4           1.4          0.3  Setosa
# 7           5.0          3.4           1.5          0.2  Setosa

# %%
#if we use loc it takes the label and it will add it to the last position of the table
df.loc[0] = [23,45,5,67,'SunFlower']

# %%
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    variety
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
# 0            23.0         45.0           5.0         67.0  SunFlower

# %%
df.loc[150] = [23,45,235,23,'Lotus']

# %%
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    variety
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
# 0            23.0         45.0           5.0         67.0  SunFlower
# 150          23.0         45.0         235.0         23.0      Lotus

# %%
df.drop(df.index[149])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-72-3df0172eab3c> in <module>
# ----> 1 df.drop(df.index[149])
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py in __getitem__(self, key)
#    4602         if is_scalar(key):
#    4603             key = com.cast_scalar_indexer(key, warn_float=True)
# -> 4604             return getitem(key)
#    4605
#    4606         if isinstance(key, slice):
#
# IndexError: index 149 is out of bounds for axis 0 with size 149

# %%
df.loc[0]
# Out:
# sepal_length         23.0
# sepal_width          45.0
# petal_length          5.0
# petal_width          67.0
# variety         SunFlower
# Name: 0, dtype: object

# %%
df.drop(0)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    variety
# 3             1.0          2.0           3.0          4.0      Tulip
# 4             5.0          3.6           1.4          0.2     Setosa
# 5             5.4          3.9           1.7          0.4     Setosa
# 6             4.6          3.4           1.4          0.3     Setosa
# 7             5.0          3.4           1.5          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
# 150          23.0         45.0         235.0         23.0      Lotus
#
# [148 rows x 5 columns]

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width variety
# 3           1.0          2.0           3.0          4.0   Tulip
# 4           5.0          3.6           1.4          0.2  Setosa
# 5           5.4          3.9           1.7          0.4  Setosa
# 6           4.6          3.4           1.4          0.3  Setosa
# 7           5.0          3.4           1.5          0.2  Setosa

# %%
df.reset_index()
# Out:
#      index  sepal_length  sepal_width  petal_length  petal_width    variety
# 0        3           1.0          2.0           3.0          4.0      Tulip
# 1        4           5.0          3.6           1.4          0.2     Setosa
# 2        5           5.4          3.9           1.7          0.4     Setosa
# 3        6           4.6          3.4           1.4          0.3     Setosa
# 4        7           5.0          3.4           1.5          0.2     Setosa
# ..     ...           ...          ...           ...          ...        ...
# 144    147           6.5          3.0           5.2          2.0  Virginica
# 145    148           6.2          3.4           5.4          2.3  Virginica
# 146    149           5.9          3.0           5.1          1.8  Virginica
# 147      0          23.0         45.0           5.0         67.0  SunFlower
# 148    150          23.0         45.0         235.0         23.0      Lotus
#
# [149 rows x 6 columns]

# %% [markdown]
# We as you can see there is a index col made and we don't want that column so to remove it we can do :

# %%
df.reset_index(drop = True, inplace=True)

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width variety
# 0           1.0          2.0           3.0          4.0   Tulip
# 1           5.0          3.6           1.4          0.2  Setosa
# 2           5.4          3.9           1.7          0.4  Setosa
# 3           4.6          3.4           1.4          0.3  Setosa
# 4           5.0          3.4           1.5          0.2  Setosa

# %%
df.drop('sepal_length',axis=1)
# Out:
#      sepal_width  petal_length  petal_width    variety
# 0            2.0           3.0          4.0      Tulip
# 1            3.6           1.4          0.2     Setosa
# 2            3.9           1.7          0.4     Setosa
# 3            3.4           1.4          0.3     Setosa
# 4            3.4           1.5          0.2     Setosa
# ..           ...           ...          ...        ...
# 144          3.0           5.2          2.0  Virginica
# 145          3.4           5.4          2.3  Virginica
# 146          3.0           5.1          1.8  Virginica
# 147         45.0           5.0         67.0  SunFlower
# 148         45.0         235.0         23.0      Lotus
#
# [149 rows x 4 columns]

# %% [markdown]
# Another way to delete

# %%
del df('sepal_width')
# Out:
#   File "<ipython-input-86-7727f913034e>", line 1
#     del df('sepal_width')
#         ^
# SyntaxError: cannot delete function call

# %%
del df['sepal_width']

# %%
df.describe()
# Out:
#        sepal_length  petal_length  petal_width
# count    149.000000    149.000000   149.000000
# mean       6.068456      5.376510     1.832886
# std        2.178646     19.017547     5.716033
# min        1.000000      1.000000     0.100000
# 25%        5.100000      1.600000     0.400000
# 50%        5.800000      4.400000     1.400000
# 75%        6.400000      5.100000     1.800000
# max       23.000000    235.000000    67.000000

# %% [markdown]
# Adding a column

# %%
df.head()
# Out:
#    sepal_length  petal_length  petal_width variety
# 0           1.0           3.0          4.0   Tulip
# 1           5.0           1.4          0.2  Setosa
# 2           5.4           1.7          0.4  Setosa
# 3           4.6           1.4          0.3  Setosa
# 4           5.0           1.5          0.2  Setosa

# %%
df['diff_pl_pw'] = df['petal_length'] - df['petal_width']
df.tail()
# Out:
#      sepal_length  petal_length  petal_width    variety  diff_pl_pw
# 144           6.5           5.2          2.0  Virginica         3.2
# 145           6.2           5.4          2.3  Virginica         3.1
# 146           5.9           5.1          1.8  Virginica         3.3
# 147          23.0           5.0         67.0  SunFlower       -62.0
# 148          23.0         235.0         23.0      Lotus       212.0
